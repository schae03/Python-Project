# %%
import pandas as pd
fish = pd.read_csv("fish2.csv")
fish.head()
# Out:
#   Species  Weight  Length  Diagonal   Height   Width
# 0   Bream   242.0    25.4      30.0  11.5200  4.0200
# 1   Bream   290.0    26.3      31.2  12.4800  4.3056
# 2   Bream   340.0    26.5      31.1  12.3778  4.6961
# 3   Bream   363.0    29.0      33.5  12.7300  4.4555
# 4   Bream   430.0    29.0      34.0  12.4440  5.1340

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Species   159 non-null    object
#  1   Weight    159 non-null    float64
#  2   Length    159 non-null    float64
#  3   Diagonal  159 non-null    float64
#  4   Height    159 non-null    float64
#  5   Width     159 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 7.6+ KB

# %%
fish['Species'].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
X = fish.drop("Species", axis = 1)
Y = fish['Species']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 0.2,
                                                   stratify=Y)

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, MaxAbsScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
box1 = {"SS" : StandardScaler(), "RO": RobustScaler(),
        "MM" : MinMaxScaler(), "MA" : MaxAbsScaler()}
box2 = ["euclidean", "manhattan"]

total = []

for i in box1:
    for j in box2:

        scaler = box1[i]
        train_scaled = scaler.fit_transform(train_x)
        test_scaled = scaler.transform(test_x)

        model = KNeighborsClassifier(metric=j)
        model.fit(train_scaled, train_y)
        
        for k in range(1, 31):
            model.n_neighbors = k
            score = model.score(test_scaled, test_y)
            total.append([i, j, k, score])

# %%
pd.DataFrame(total, columns = ['표준화', '거리계산', '이웃수', '정확도']).sort_values("정확도", ascending = False)
# Out:
#     표준화       거리계산  이웃수      정확도
# 120  MM  euclidean    1  0.90625
# 180  MA  euclidean    1  0.90625
# 30   SS  manhattan    1  0.87500
# 210  MA  manhattan    1  0.87500
# 150  MM  manhattan    1  0.87500
# ..   ..        ...  ...      ...
# 87   RO  euclidean   28  0.62500
# 88   RO  euclidean   29  0.62500
# 89   RO  euclidean   30  0.62500
# 59   SS  manhattan   30  0.62500
# 239  MA  manhattan   30  0.62500
#
# [240 rows x 4 columns]

# %%
mm = MinMaxScaler()
train_scaled = mm.fit_transform(train_x)
test_scaled = mm.transform(test_x)

model = KNeighborsClassifier(metric="euclidean", n_neighbors=1)
model.fit(train_scaled, train_y)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=1)

# %%
from sklearn.metrics import classification_report
pred = model.predict(test_scaled)
report = classification_report(test_y, pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Bream       1.00      1.00      1.00         7
#       Parkki       1.00      1.00      1.00         2
#        Perch       0.91      0.91      0.91        11
#         Pike       1.00      1.00      1.00         4
#        Roach       1.00      0.50      0.67         4
#        Smelt       0.75      1.00      0.86         3
#    Whitefish       0.50      1.00      0.67         1
#
#     accuracy                           0.91        32
#    macro avg       0.88      0.92      0.87        32
# weighted avg       0.93      0.91      0.90        32
