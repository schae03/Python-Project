# %%
import pandas as pd

fish = pd.read_csv("Data/fish2.csv") 
fish.head()
# Out:
#   Species  Weight  Length  Diagonal   Height   Width
# 0   Bream   242.0    25.4      30.0  11.5200  4.0200
# 1   Bream   290.0    26.3      31.2  12.4800  4.3056
# 2   Bream   340.0    26.5      31.1  12.3778  4.6961
# 3   Bream   363.0    29.0      33.5  12.7300  4.4555
# 4   Bream   430.0    29.0      34.0  12.4440  5.1340

# %%
fish["Species"].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
# 문제집과 정답지
X = fish.drop("Species", axis = 1)
Y = fish["Species"]

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 0.2, 
                                                    stratify = Y)
                                                    # stratify=Y 주면 거의 안뽑히는거없이 비율 맞춰서 뽑아줌

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, MaxAbsScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
box1 = {"SS" : StandardScaler(), "RO" : RobustScaler(),
        "MM" : MinMaxScaler(), "MA" : MaxAbsScaler()}
box2 = ["euclidean", "manhattan"]

total = []

for i in box1:
    for j in box2:
        scaler = box1[i]          # standscaler가져옴
        train_scaled = scaler.fit_transform(train_x)       # 표준화
        test_scaled = scaler.transform(test_x)
        
        # 모델학습
        model = KNeighborsClassifier(metric=j)
        model.fit(train_scaled, train_y)
        
        for k in range(1,31):
            model.n_neighbors = k       # 모델이 k개일때 성능 파악
            score = model.score(test_scaled, test_y)
            total.append([i, j, k, score])

# %%
pd.DataFrame(total, columns = ["표준화", "거리계산", "이웃수", "정확도"]).sort_values("정확도", ascending=False)

# 가장좋을때의 옵션값들 확인 가능
# Out:
#     표준화       거리계산  이웃수      정확도
# 0    SS  euclidean    1  0.90625
# 60   RO  euclidean    1  0.90625
# 180  MA  euclidean    1  0.90625
# 120  MM  euclidean    1  0.90625
# 122  MM  euclidean    3  0.84375
# ..   ..        ...  ...      ...
# 147  MM  euclidean   28  0.56250
# 148  MM  euclidean   29  0.56250
# 149  MM  euclidean   30  0.56250
# 207  MA  euclidean   28  0.56250
# 29   SS  euclidean   30  0.56250
#
# [240 rows x 4 columns]

# %%
mm = MinMaxScaler()
train_scaled = mm.fit_transform(train_x)
test_scaled = mm.transform(test_x)

mm = MinMaxScaler()
train_scaled = mm.fit_transform(train_x)
test_scaled = mm.transform(test_x)

model = KNeighborsClassifier(metric="euclidean", n_neighbors=1)
model.fit(train_scaled, train_y)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=1)

# %%
from sklearn.metrics import classification_report
pred = model.predict(test_scaled)
report = classification_report(test_y, pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Bream       1.00      1.00      1.00         7
#       Parkki       1.00      1.00      1.00         2
#        Perch       0.90      0.82      0.86        11
#         Pike       1.00      1.00      1.00         4
#        Roach       0.67      1.00      0.80         4
#        Smelt       1.00      1.00      1.00         3
#    Whitefish       0.00      0.00      0.00         1
#
#     accuracy                           0.91        32
#    macro avg       0.80      0.83      0.81        32
# weighted avg       0.89      0.91      0.89        32
# C:\Users\campus4D019\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\campus4D019\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\campus4D019\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
